# %%
import numpy as np

# Load the file with old numpy and re-save it
try:
    data = np.load("your_file.npy", allow_pickle=True)
    np.save("your_file_fixed.npy", data)
    print("File re-saved successfully")
except Exception as e:
    print(f"Error: {e}")
